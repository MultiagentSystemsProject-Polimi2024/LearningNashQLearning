# %%
import os
os.chdir('./LearningNashQLearning')
# !python ./setup.py sdist bdist_wheel
#!pip install ./dist/LearningNashQLearning-0.9-py3-none-any.whl --force-reinstall
os.chdir('../')
# Out:
# running sdist
# running egg_info
# writing LearningNashQLearning.egg-info\PKG-INFO
# writing dependency_links to LearningNashQLearning.egg-info\dependency_links.txt
# writing requirements to LearningNashQLearning.egg-info\requires.txt
# writing top-level names to LearningNashQLearning.egg-info\top_level.txt
# reading manifest file 'LearningNashQLearning.egg-info\SOURCES.txt'
# writing manifest file 'LearningNashQLearning.egg-info\SOURCES.txt'
# running check
# creating LearningNashQLearning-0.12
# creating LearningNashQLearning-0.12\LearningNashQLearning
# creating LearningNashQLearning-0.12\LearningNashQLearning.egg-info
# creating LearningNashQLearning-0.12\LearningNashQLearning\Model
# creating LearningNashQLearning-0.12\LearningNashQLearning\View
# copying files to LearningNashQLearning-0.12...
# copying README.md -> LearningNashQLearning-0.12
# copying pyproject.toml -> LearningNashQLearning-0.12
# copying setup.py -> LearningNashQLearning-0.12
# copying LearningNashQLearning\__init__.py -> LearningNashQLearning-0.12\LearningNashQLearning
# copying LearningNashQLearning.egg-info\PKG-INFO -> LearningNashQLearning-0.12\LearningNashQLearning.egg-info
# copying LearningNashQLearning.egg-info\SOURCES.txt -> LearningNashQLearning-0.12\LearningNashQLearning.egg-info
# copying LearningNashQLearning.egg-info\dependency_links.txt -> LearningNashQLearning-0.12\LearningNashQLearning.egg-info
# copying LearningNashQLearning.egg-info\requires.txt -> LearningNashQLearning-0.12\LearningNashQLearning.egg-info
# copying LearningNashQLearning.egg-info\top_level.txt -> LearningNashQLearning-0.12\LearningNashQLearning.egg-info
# copying LearningNashQLearning\Model\Environment.py -> LearningNashQLearning-0.12\LearningNashQLearning\Model
# copying LearningNashQLearning\Model\History.py -> LearningNashQLearning-0.12\LearningNashQLearning\Model
# copying LearningNashQLearning\Model\NashQLearning.py -> LearningNashQLearning-0.12\LearningNashQLearning\Model
# copying LearningNashQLearning\Model\__init__.py -> LearningNashQLearning-0.12\LearningNashQLearning\Model
# copying LearningNashQLearning\View\EnvGraphDisplay.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# copying LearningNashQLearning\View\FinalDisplay.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# copying LearningNashQLearning\View\GameEditor.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# copying LearningNashQLearning\View\GraphClass.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# copying LearningNashQLearning\View\GridDisplay.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# copying LearningNashQLearning\View\PresetGames.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# copying LearningNashQLearning\View\__init__.py -> LearningNashQLearning-0.12\LearningNashQLearning\View
# Writing LearningNashQLearning-0.12\setup.cfg
# Creating tar archive
# removing 'LearningNashQLearning-0.12' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# installing to build\bdist.win-amd64\wheel
# running install
# running install_lib
# creating build\bdist.win-amd64\wheel
# creating build\bdist.win-amd64\wheel\LearningNashQLearning
# copying build\lib\LearningNashQLearning\main.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning
# creating build\bdist.win-amd64\wheel\LearningNashQLearning\Model
# copying build\lib\LearningNashQLearning\Model\Agent.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\Model
# copying build\lib\LearningNashQLearning\Model\Environment.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\Model
# copying build\lib\LearningNashQLearning\Model\History.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\Model
# copying build\lib\LearningNashQLearning\Model\NashQLearning.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\Model
# copying build\lib\LearningNashQLearning\Model\__init__.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\Model
# creating build\bdist.win-amd64\wheel\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\EnvGraphDisplay.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\FinalDisplay.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\GameEditor.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\GraphClass.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\GridDisplay.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\NashQLearningWidgets.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\PresetGames.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\View\__init__.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning\View
# copying build\lib\LearningNashQLearning\__init__.py -> build\bdist.win-amd64\wheel\.\LearningNashQLearning
# running install_egg_info
# Copying LearningNashQLearning.egg-info to build\bdist.win-amd64\wheel\.\LearningNashQLearning-0.12-py3.10.egg-info
# running install_scripts
# creating build\bdist.win-amd64\wheel\LearningNashQLearning-0.12.dist-info\WHEEL
# creating 'dist\LearningNashQLearning-0.12-py3-none-any.whl' and adding 'build\bdist.win-amd64\wheel' to it
# adding 'LearningNashQLearning/__init__.py'
# adding 'LearningNashQLearning/main.py'
# adding 'LearningNashQLearning/Model/Agent.py'
# adding 'LearningNashQLearning/Model/Environment.py'
# adding 'LearningNashQLearning/Model/History.py'
# adding 'LearningNashQLearning/Model/NashQLearning.py'
# adding 'LearningNashQLearning/Model/__init__.py'
# adding 'LearningNashQLearning/View/EnvGraphDisplay.py'
# adding 'LearningNashQLearning/View/FinalDisplay.py'
# adding 'LearningNashQLearning/View/GameEditor.py'
# adding 'LearningNashQLearning/View/GraphClass.py'
# adding 'LearningNashQLearning/View/GridDisplay.py'
# adding 'LearningNashQLearning/View/NashQLearningWidgets.py'
# adding 'LearningNashQLearning/View/PresetGames.py'
# adding 'LearningNashQLearning/View/__init__.py'
# adding 'LearningNashQLearning-0.12.dist-info/METADATA'
# adding 'LearningNashQLearning-0.12.dist-info/WHEEL'
# adding 'LearningNashQLearning-0.12.dist-info/top_level.txt'
# adding 'LearningNashQLearning-0.12.dist-info/RECORD'
# removing build\bdist.win-amd64\wheel
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:196: UserWarning: `install_requires` overwritten in `pyproject.toml` (dependencies)
#   warnings.warn(msg)
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(

# %%
from LearningNashQLearning.Model.Environment import Environment
from LearningNashQLearning.Model.NashQLearning import NashQLearning
from LearningNashQLearning.View.PresetGames import PresetGames
from LearningNashQLearning.View.GameEditor import EnvironmentWidget
from LearningNashQLearning.View.EnvGraphDisplay import EnvGraphDisplay
from LearningNashQLearning.View.FinalDisplay import FinalDisplay



import ipywidgets as widgets
from IPython.display import display

# %matplotlib widget


# autoreload   
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Publish on pip

# %%
#read from file
apiToken = ""
with open("apiToken.txt", "r") as file:
    apiToken = file.read()

os.chdir('./LearningNashQLearning')
# !twine upload --user __token__ --password {apiToken} dist/*
os.chdir('../')
# Out:
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading LearningNashQLearning-0.11-py3-none-any.whl
#
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
#   0% ---------------------------------------- 0.0/30.1 kB • --:-- • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# 100% ---------------------------------------- 30.1/30.1 kB • 00:00 • ?
# Uploading LearningNashQLearning-0.11.tar.gz
#
#   0% ---------------------------------------- 0.0/22.4 kB • --:-- • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
# 100% ---------------------------------------- 22.4/22.4 kB • 00:00 • ?
#
# View at:
# https://pypi.org/project/LearningNashQLearning/0.11/
