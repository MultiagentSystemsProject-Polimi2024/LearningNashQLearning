# %%
from NashQLearning import *
from Environment import *

# %%
env = Environment()

games = env.getGames()

games[0].setPossibleActions(np.array([2, 2]))
#games[0].setPossibleActions((2, 2))
print("–––––––––––")
print(games[0])
games[0].setTransition((0, 0), 1, 1)
games[0].setPayoff((0, 0), np.array([1,1]))
print("–––––––––––")
print(games[0])
games[0].setTransition((1, 0), 0, 1)
games[0].setPayoff((1, 0), np.array([0,0]))
print("–––––––––––")
print(games[0])
games[0].setTransition((0, 1), 0, 1)
games[0].setPayoff((0, 1), np.array([0,0]))
print("–––––––––––")
print(games[0])
games[0].setTransition((1, 1), 0, 1)
games[0].setPayoff((1, 1), np.array([-1,-1]))
print("–––––––––––")
print(games[0])
###############################################

games[1].setPossibleActions(np.array([2, 2]))
#games[1].setPossibleActions((2, 2))
print("–––––––––––")
print(games[1])
games[1].setTransition((0, 0), 0, 1)
games[1].setPayoff((0, 0), np.array([1,1]))
print("–––––––––––")
print(games[1])

games[1].setTransition((1, 0), 1, 1)
games[1].setPayoff((1, 0), np.array([0,0]))
print("–––––––––––")
print(games[1])

games[1].setTransition((0, 1), 1, 1)
games[1].setPayoff((0, 1), np.array([0,0]))
print("–––––––––––")
print(games[1])

games[1].setTransition((1, 1), 1, 1)
games[1].setPayoff((1, 1), np.array([-1,-1]))
print("–––––––––––")
print(games[1])
# Out:
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{}', '{}', '{}', '{}']
#  Payoff: [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{}', '{}', '{}']
#  Payoff: [[[1. 1.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{}', '{0: 1}', '{}']
#  Payoff: [[[1. 1.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{}']
#  Payoff: [[[1. 1.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{}', '{}', '{}', '{}']
#  Payoff: [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{}', '{}', '{}']
#  Payoff: [[[1. 1.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{}', '{1: 1}', '{}']
#  Payoff: [[[1. 1.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{}']
#  Payoff: [[[1. 1.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# –––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]

# %%
#env.getNextState(np.array([0,0]))
for game in env.getGames():
    print("–––––––––––––––––")
    print(game)
# Out:
# –––––––––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# –––––––––––––––––
# Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]

# %%
learn = NashQLearning(environment=env, startingState=games[0])
learn.setEpisodes(2000)
totR, diffs, Rew, H = learn.nashQlearning(0.5, 0.8, 0.1, 1500, 1500, False)
# Out:
# IntProgress(value=0, bar_style='info', description='Games:', max=0)

# %%
print(H)
# Out:
# Q0 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# Q1 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 0 Q0 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# Q1 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# Q1: [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# Q1 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 1 Q0 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# Q1 [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# Q1: [[[0. 0.]
#   [0. 0.]]
#
#  [[0. 0.]
#   [0. 0.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 2 Q0 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1: [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 3 Q0 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1: [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 4 Q0 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1: [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 5 Q0 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# Q1: [[[ 0.   0. ]
#   [ 0.   0. ]]
#
#  [[ 0.   0. ]
#   [-0.5 -0.5]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 6 Q0 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1: [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 7 Q0 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1: [[[ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.7   0.7 ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.7   0.7 ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 8 Q0 [[[ 0.7   0.7 ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.7   0.7 ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.7   0.7 ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1: [[[ 0.7   0.7 ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.2  0.2]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.2  0.2]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 9 Q0 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.2  0.2]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.2  0.2]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.2  0.2]
#   [-0.5 -0.5]]]
# Q1: [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.2  0.2]
#   [-0.5 -0.5]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.3  0.3]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.3  0.3]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 10 Q0 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.3  0.3]
#   [-0.5 -0.5]]]
# Q1 [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.3  0.3]
#   [-0.5 -0.5]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.3  0.3]
#   [-0.5 -0.5]]]
# Q1: [[[ 0.5  0.5]
#   [ 0.   0. ]]
#
#  [[ 0.3  0.3]
#   [-0.5 -0.5]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5   0.5 ]
#   [ 0.    0.  ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.    0.  ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 11 Q0 [[[ 0.5   0.5 ]
#   [ 0.    0.  ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.    0.  ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5   0.5 ]
#   [ 0.    0.  ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# Q1: [[[ 0.5   0.5 ]
#   [ 0.    0.  ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 12 Q0 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# Q1: [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.3   0.3 ]
#   [-0.55 -0.55]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 13 Q0 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1: [[[ 0.5   0.5 ]
#   [ 0.2   0.2 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5   0.5 ]
#   [ 0.3   0.3 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.3   0.3 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 14 Q0 [[[ 0.5   0.5 ]
#   [ 0.3   0.3 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.3   0.3 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5   0.5 ]
#   [ 0.3   0.3 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1: [[[ 0.5   0.5 ]
#   [ 0.3   0.3 ]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5   0.5 ]
#   [ 0.35  0.35]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.35  0.35]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 15 Q0 [[[ 0.5   0.5 ]
#   [ 0.35  0.35]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1 [[[ 0.5   0.5 ]
#   [ 0.35  0.35]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5   0.5 ]
#   [ 0.35  0.35]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# Q1: [[[ 0.5   0.5 ]
#   [ 0.35  0.35]]
#
#  [[ 0.35  0.35]
#   [-0.55 -0.55]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.5    0.5  ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# Q1 [[[ 0.5    0.5  ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 16 Q0 [[[ 0.5    0.5  ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# Q1 [[[ 0.5    0.5  ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.5    0.5  ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# Q1: [[[ 0.5    0.5  ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.03   1.03 ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# Q1 [[[ 1.03   1.03 ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 17 Q0 [[[ 1.03   1.03 ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# Q1 [[[ 1.03   1.03 ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.03   1.03 ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# Q1: [[[ 1.03   1.03 ]
#   [ 0.35   0.35 ]]
#
#  [[ 0.35   0.35 ]
#   [-0.575 -0.575]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.7   0.7 ]
#   [ 0.28  0.28]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.7   0.7 ]
#   [ 0.28  0.28]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 18 Q0 [[[ 0.7   0.7 ]
#   [ 0.28  0.28]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1 [[[ 0.7   0.7 ]
#   [ 0.28  0.28]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.7   0.7 ]
#   [ 0.28  0.28]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# Q1: [[[ 0.7   0.7 ]
#   [ 0.28  0.28]]
#
#  [[ 0.    0.  ]
#   [-0.75 -0.75]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 0.7    0.7  ]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# Q1 [[[ 0.7    0.7  ]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 19 Q0 [[[ 0.7    0.7  ]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# Q1 [[[ 0.7    0.7  ]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 0.7    0.7  ]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# Q1: [[[ 0.7    0.7  ]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262  1.262]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# Q1 [[[ 1.262  1.262]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 20 Q0 [[[ 1.262  1.262]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# Q1 [[[ 1.262  1.262]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262  1.262]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# Q1: [[[ 1.262  1.262]
#   [ 0.28   0.28 ]]
#
#  [[ 0.     0.   ]
#   [-0.595 -0.595]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.03    1.03  ]
#   [ 0.35    0.35  ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1 [[[ 1.03    1.03  ]
#   [ 0.35    0.35  ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 21 Q0 [[[ 1.03    1.03  ]
#   [ 0.35    0.35  ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1 [[[ 1.03    1.03  ]
#   [ 0.35    0.35  ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.03    1.03  ]
#   [ 0.35    0.35  ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1: [[[ 1.03    1.03  ]
#   [ 0.35    0.35  ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.03    1.03  ]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1 [[[ 1.03    1.03  ]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 22 Q0 [[[ 1.03    1.03  ]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1 [[[ 1.03    1.03  ]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.03    1.03  ]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1: [[[ 1.03    1.03  ]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.5198  1.5198]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1 [[[ 1.5198  1.5198]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 23 Q0 [[[ 1.5198  1.5198]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1 [[[ 1.5198  1.5198]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.5198  1.5198]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# Q1: [[[ 1.5198  1.5198]
#   [ 0.587   0.587 ]]
#
#  [[ 0.35    0.35  ]
#   [-0.3755 -0.3755]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.      0.    ]
#   [-0.2927 -0.2927]]]
# Q1 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.      0.    ]
#   [-0.2927 -0.2927]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 24 Q0 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.      0.    ]
#   [-0.2927 -0.2927]]]
# Q1 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.      0.    ]
#   [-0.2927 -0.2927]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.      0.    ]
#   [-0.2927 -0.2927]]]
# Q1: [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.      0.    ]
#   [-0.2927 -0.2927]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.5048  0.5048]
#   [-0.2927 -0.2927]]]
# Q1 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.5048  0.5048]
#   [-0.2927 -0.2927]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 25 Q0 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.5048  0.5048]
#   [-0.2927 -0.2927]]]
# Q1 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.5048  0.5048]
#   [-0.2927 -0.2927]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.5048  0.5048]
#   [-0.2927 -0.2927]]]
# Q1: [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.5048  0.5048]
#   [-0.2927 -0.2927]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.7572  0.7572]
#   [-0.2927 -0.2927]]]
# Q1 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.7572  0.7572]
#   [-0.2927 -0.2927]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 26 Q0 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.7572  0.7572]
#   [-0.2927 -0.2927]]]
# Q1 [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.7572  0.7572]
#   [-0.2927 -0.2927]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.7572  0.7572]
#   [-0.2927 -0.2927]]]
# Q1: [[[ 1.262   1.262 ]
#   [ 0.28    0.28  ]]
#
#  [[ 0.7572  0.7572]
#   [-0.2927 -0.2927]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262    1.262  ]
#   [ 0.28     0.28   ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.28     0.28   ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 27 Q0 [[[ 1.262    1.262  ]
#   [ 0.28     0.28   ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.28     0.28   ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262    1.262  ]
#   [ 0.28     0.28   ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1: [[[ 1.262    1.262  ]
#   [ 0.28     0.28   ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262    1.262  ]
#   [ 0.6448   0.6448 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.6448   0.6448 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 28 Q0 [[[ 1.262    1.262  ]
#   [ 0.6448   0.6448 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.6448   0.6448 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262    1.262  ]
#   [ 0.6448   0.6448 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1: [[[ 1.262    1.262  ]
#   [ 0.6448   0.6448 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 29 Q0 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# Q1: [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.7572   0.7572 ]
#   [-0.14155 -0.14155]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 30 Q0 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# Q1: [[[ 1.262    1.262  ]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.73892  1.73892]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.73892  1.73892]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 31 Q0 [[[ 1.73892  1.73892]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# Q1 [[[ 1.73892  1.73892]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.73892  1.73892]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# Q1: [[[ 1.73892  1.73892]
#   [ 0.8272   0.8272 ]]
#
#  [[ 0.8834   0.8834 ]
#   [-0.14155 -0.14155]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.955468  1.955468]
#   [ 0.587     0.587   ]]
#
#  [[ 0.35      0.35    ]
#   [-0.3755   -0.3755  ]]]
# Q1 [[[ 1.955468  1.955468]
#   [ 0.587     0.587   ]]
#
#  [[ 0.35      0.35    ]
#   [-0.3755   -0.3755  ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 32 Q0 [[[ 1.955468  1.955468]
#   [ 0.587     0.587   ]]
#
#  [[ 0.35      0.35    ]
#   [-0.3755   -0.3755  ]]]
# Q1 [[[ 1.955468  1.955468]
#   [ 0.587     0.587   ]]
#
#  [[ 0.35      0.35    ]
#   [-0.3755   -0.3755  ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.955468  1.955468]
#   [ 0.587     0.587   ]]
#
#  [[ 0.35      0.35    ]
#   [-0.3755   -0.3755  ]]]
# Q1: [[[ 1.955468  1.955468]
#   [ 0.587     0.587   ]]
#
#  [[ 0.35      0.35    ]
#   [-0.3755   -0.3755  ]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[0.8834   0.8834  ]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[0.8834   0.8834  ]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 33 Q0 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[0.8834   0.8834  ]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[0.8834   0.8834  ]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[0.8834   0.8834  ]
#   [0.124793 0.124793]]]
# Q1: [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[0.8834   0.8834  ]
#   [0.124793 0.124793]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 34 Q0 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1: [[[1.73892  1.73892 ]
#   [0.8272   0.8272  ]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892  1.73892 ]
#   [1.109168 1.109168]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [1.109168 1.109168]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 35 Q0 [[[1.73892  1.73892 ]
#   [1.109168 1.109168]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [1.109168 1.109168]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892  1.73892 ]
#   [1.109168 1.109168]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1: [[[1.73892  1.73892 ]
#   [1.109168 1.109168]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892  1.73892 ]
#   [1.250152 1.250152]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [1.250152 1.250152]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 36 Q0 [[[1.73892  1.73892 ]
#   [1.250152 1.250152]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1 [[[1.73892  1.73892 ]
#   [1.250152 1.250152]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892  1.73892 ]
#   [1.250152 1.250152]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# Q1: [[[1.73892  1.73892 ]
#   [1.250152 1.250152]]
#
#  [[1.137268 1.137268]
#   [0.124793 0.124793]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892   1.73892  ]
#   [1.250152  1.250152 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# Q1 [[[1.73892   1.73892  ]
#   [1.250152  1.250152 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 37 Q0 [[[1.73892   1.73892  ]
#   [1.250152  1.250152 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# Q1 [[[1.73892   1.73892  ]
#   [1.250152  1.250152 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892   1.73892  ]
#   [1.250152  1.250152 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# Q1: [[[1.73892   1.73892  ]
#   [1.250152  1.250152 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892   1.73892  ]
#   [1.320644  1.320644 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# Q1 [[[1.73892   1.73892  ]
#   [1.320644  1.320644 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 38 Q0 [[[1.73892   1.73892  ]
#   [1.320644  1.320644 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# Q1 [[[1.73892   1.73892  ]
#   [1.320644  1.320644 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892   1.73892  ]
#   [1.320644  1.320644 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# Q1: [[[1.73892   1.73892  ]
#   [1.320644  1.320644 ]]
#
#  [[1.137268  1.137268 ]
#   [0.2579645 0.2579645]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.32455025 0.32455025]]]
# Q1 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.32455025 0.32455025]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 39 Q0 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.32455025 0.32455025]]]
# Q1 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.32455025 0.32455025]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.32455025 0.32455025]]]
# Q1: [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.32455025 0.32455025]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# Q1 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 40 Q0 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# Q1 [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# Q1: [[[1.73892    1.73892   ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# Q1 [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 41 Q0 [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# Q1 [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# Q1: [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.35784313 0.35784313]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 0.9571872  0.9571872]
#   [-0.3755    -0.3755   ]]]
# Q1 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 0.9571872  0.9571872]
#   [-0.3755    -0.3755   ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 42 Q0 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 0.9571872  0.9571872]
#   [-0.3755    -0.3755   ]]]
# Q1 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 0.9571872  0.9571872]
#   [-0.3755    -0.3755   ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 0.9571872  0.9571872]
#   [-0.3755    -0.3755   ]]]
# Q1: [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 0.9571872  0.9571872]
#   [-0.3755    -0.3755   ]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 1.2607808  1.2607808]
#   [-0.3755    -0.3755   ]]]
# Q1 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 1.2607808  1.2607808]
#   [-0.3755    -0.3755   ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 43 Q0 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 1.2607808  1.2607808]
#   [-0.3755    -0.3755   ]]]
# Q1 [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 1.2607808  1.2607808]
#   [-0.3755    -0.3755   ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 1.2607808  1.2607808]
#   [-0.3755    -0.3755   ]]]
# Q1: [[[ 1.955468   1.955468 ]
#   [ 0.587      0.587    ]]
#
#  [[ 1.2607808  1.2607808]
#   [-0.3755    -0.3755   ]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[ 2.33839288  2.33839288]
#   [ 0.587       0.587     ]]
#
#  [[ 1.2607808   1.2607808 ]
#   [-0.3755     -0.3755    ]]]
# Q1 [[[ 2.33839288  2.33839288]
#   [ 0.587       0.587     ]]
#
#  [[ 1.2607808   1.2607808 ]
#   [-0.3755     -0.3755    ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# 44 Q0 [[[ 2.33839288  2.33839288]
#   [ 0.587       0.587     ]]
#
#  [[ 1.2607808   1.2607808 ]
#   [-0.3755     -0.3755    ]]]
# Q1 [[[ 2.33839288  2.33839288]
#   [ 0.587       0.587     ]]
#
#  [[ 1.2607808   1.2607808 ]
#   [-0.3755     -0.3755    ]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
# Q0: [[[ 2.33839288  2.33839288]
#   [ 0.587       0.587     ]]
#
#  [[ 1.2607808   1.2607808 ]
#   [-0.3755     -0.3755    ]]]
# Q1: [[[ 2.33839288  2.33839288]
#   [ 0.587       0.587     ]]
#
#  [[ 1.2607808   1.2607808 ]
#   [-0.3755     -0.3755    ]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# Q0 [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.53958044 0.53958044]]]
# Q1 [[[2.1516472  2.1516472 ]
#   [1.320644   1.320644  ]]
#
#  [[1.137268   1.137268  ]
#   [0.53958044 0.53958044]]]
# current_state Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
# ...
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1945: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1946: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1947: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1948: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1949: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1950: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1951: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1952: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1953: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1954: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1955: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1956: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1957: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1958: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1959: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1960: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1961: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1962: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1963: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1964: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1965: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1966: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1967: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1968: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1969: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1970: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1971: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1972: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1973: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1974: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1975: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1976: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1977: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1978: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1979: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1980: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1981: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1982: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1983: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1984: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1985: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1986: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1987: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1988: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1989: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1990: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1991: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1992: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1993: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1994: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{0: 1}', '{1: 1}', '{1: 1}', '{1: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1995: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1996: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1997: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1998: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
#
# 1999: Q0: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# Q1: [[[5. 5.]
#   [4. 4.]]
#
#  [[4. 4.]
#   [3. 3.]]]
# current_state: Game: [2 2]
#  PossibileActions:[2 2]
#  NPlayers: 2
#  Transition: ['{1: 1}', '{0: 1}', '{0: 1}', '{0: 1}']
#  Payoff: [[[ 1.  1.]
#   [ 0.  0.]]
#
#  [[ 0.  0.]
#   [-1. -1.]]]
